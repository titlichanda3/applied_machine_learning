# %%
# !pip install dvc
# Out:
# Requirement already satisfied: dvc in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (3.66.1)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from dvc) (24.2.0)
# Requirement already satisfied: celery in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from dvc) (5.6.2)
# Requirement already satisfied: colorama>=0.3.9 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from dvc) (0.4.6)
# Requirement already satisfied: configobj>=5.0.9 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from dvc) (5.0.9)
# Requirement already satisfied: distro>=1.3 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from dvc) (1.9.0)
# Requirement already satisfied: dpath<3,>=2.1.0 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from dvc) (2.2.0)
# Requirement already satisfied: dulwich in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from dvc) (1.0.0)
# Requirement already satisfied: dvc-data<3.19.0,>=3.18.0 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from dvc) (3.18.2)
# Requirement already satisfied: dvc-http>=2.29.0 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from dvc) (2.32.0)
# Requirement already satisfied: dvc-objects in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from dvc) (5.2.0)
# Requirement already satisfied: dvc-render<2,>=1.0.1 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from dvc) (1.0.2)
# Requirement already satisfied: dvc-studio-client<1,>=0.21 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from dvc) (0.22.0)
# Requirement already satisfied: dvc-task<1,>=0.3.0 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from dvc) (0.40.2)
# Requirement already satisfied: flatten-dict<1,>=0.4.1 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from dvc) (0.4.2)
# Requirement already satisfied: flufl.lock<10,>=8.1.0 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from dvc) (9.0.0)
# Requirement already satisfied: fsspec>=2024.2.0 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from dvc) (2025.5.1)
# Requirement already satisfied: funcy>=1.14 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from dvc) (2.0)
# Requirement already satisfied: grandalf<1,>=0.7 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from dvc) (0.8)
# Requirement already satisfied: gto<2,>=1.6.0 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from dvc) (1.9.0)
# Requirement already satisfied: hydra-core>=1.1 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from dvc) (1.3.2)
# Requirement already satisfied: iterative-telemetry>=0.0.7 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from dvc) (0.0.10)
# Requirement already satisfied: kombu in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from dvc) (5.6.2)
# Requirement already satisfied: networkx>=2.5 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from dvc) (3.5)
# Requirement already satisfied: omegaconf in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from dvc) (2.3.0)
# Requirement already satisfied: packaging>=19 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from dvc) (24.1)
# Requirement already satisfied: pathspec<1,>=0.10.3 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from dvc) (0.12.1)
# Requirement already satisfied: platformdirs<5,>=3.1.1 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from dvc) (4.2.2)
# Requirement already satisfied: psutil>=5.8 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from dvc) (6.0.0)
# Requirement already satisfied: pydot>=1.2.4 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from dvc) (4.0.1)
# Requirement already satisfied: pygtrie>=2.3.2 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from dvc) (2.5.0)
# Requirement already satisfied: pyparsing>=2.4.7 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from dvc) (3.2.1)
# Requirement already satisfied: requests>=2.22 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from dvc) (2.32.3)
# Requirement already satisfied: rich>=12 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from dvc) (14.1.0)
# Requirement already satisfied: ruamel.yaml>=0.17.11 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from dvc) (0.19.1)
# Requirement already satisfied: scmrepo<4,>=3.5.2 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from dvc) (3.6.1)
# Requirement already satisfied: shortuuid>=0.5 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from dvc) (1.0.13)
# Requirement already satisfied: shtab<2,>=1.3.4 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from dvc) (1.8.0)
# Requirement already satisfied: tabulate>=0.8.7 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from dvc) (0.9.0)
# Requirement already satisfied: tomlkit>=0.11.1 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from dvc) (0.14.0)
# Requirement already satisfied: tqdm<5,>=4.63.1 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from dvc) (4.66.5)
# Requirement already satisfied: voluptuous>=0.11.7 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from dvc) (0.16.0)
# Requirement already satisfied: zc.lockfile>=1.2.1 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from dvc) (4.0)
# Requirement already satisfied: dictdiffer>=0.8.1 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from dvc-data<3.19.0,>=3.18.0->dvc) (0.9.0)
# Requirement already satisfied: diskcache>=5.2.1 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from dvc-data<3.19.0,>=3.18.0->dvc) (5.6.3)
# Requirement already satisfied: sqltrie<1,>=0.11.0 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from dvc-data<3.19.0,>=3.18.0->dvc) (0.11.2)
# Requirement already satisfied: orjson<4,>=3 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from dvc-data<3.19.0,>=3.18.0->dvc) (3.11.7)
# Requirement already satisfied: pywin32>=225 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from dvc-task<1,>=0.3.0->dvc) (306)
# Requirement already satisfied: billiard<5.0,>=4.2.1 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from celery->dvc) (4.2.4)
# Requirement already satisfied: vine<6.0,>=5.1.0 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from celery->dvc) (5.1.0)
# Requirement already satisfied: click<9.0,>=8.1.2 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from celery->dvc) (8.1.7)
# Requirement already satisfied: click-didyoumean>=0.3.0 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from celery->dvc) (0.3.1)
# Requirement already satisfied: click-repl>=0.2.0 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from celery->dvc) (0.3.0)
# Requirement already satisfied: click-plugins>=1.1.1 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from celery->dvc) (1.1.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from celery->dvc) (2.9.0.post0)
# Requirement already satisfied: tzlocal in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from celery->dvc) (5.3.1)
# Requirement already satisfied: six<2.0,>=1.12 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from flatten-dict<1,>=0.4.1->dvc) (1.16.0)
# Requirement already satisfied: atpublic in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from flufl.lock<10,>=8.1.0->dvc) (7.0.0)
# Requirement already satisfied: entrypoints in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from gto<2,>=1.6.0->dvc) (0.4)
# Requirement already satisfied: pydantic>=2 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from gto<2,>=1.6.0->dvc) (2.11.7)
# Requirement already satisfied: pydantic-settings>=2 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from gto<2,>=1.6.0->dvc) (2.12.0)
# Requirement already satisfied: semver>=2.13.0 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from gto<2,>=1.6.0->dvc) (3.0.4)
# Requirement already satisfied: typer>=0.4.1 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from gto<2,>=1.6.0->dvc) (0.21.1)
# Requirement already satisfied: amqp<6.0.0,>=5.1.1 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from kombu->dvc) (5.3.1)
# Requirement already satisfied: tzdata>=2025.2 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from kombu->dvc) (2025.3)
# Requirement already satisfied: gitpython>3 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from scmrepo<4,>=3.5.2->dvc) (3.1.45)
# Requirement already satisfied: pygit2>=1.14.0 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from scmrepo<4,>=3.5.2->dvc) (1.19.1)
# Requirement already satisfied: asyncssh<3,>=2.13.1 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from scmrepo<4,>=3.5.2->dvc) (2.22.0)
# Requirement already satisfied: aiohttp-retry>=2.5.0 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from scmrepo<4,>=3.5.2->dvc) (2.9.1)
# Requirement already satisfied: cryptography>=39.0 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from asyncssh<3,>=2.13.1->scmrepo<4,>=3.5.2->dvc) (46.0.4)
# Requirement already satisfied: typing_extensions>=4.0.0 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from asyncssh<3,>=2.13.1->scmrepo<4,>=3.5.2->dvc) (4.13.2)
# Requirement already satisfied: aiohttp in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from aiohttp-retry>=2.5.0->scmrepo<4,>=3.5.2->dvc) (3.12.15)
# Requirement already satisfied: prompt-toolkit>=3.0.36 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from click-repl>=0.2.0->celery->dvc) (3.0.47)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from cryptography>=39.0->asyncssh<3,>=2.13.1->scmrepo<4,>=3.5.2->dvc) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from cffi>=2.0.0->cryptography>=39.0->asyncssh<3,>=2.13.1->scmrepo<4,>=3.5.2->dvc) (2.22)
# Requirement already satisfied: urllib3>=2.2.2 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from dulwich->dvc) (2.4.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from gitpython>3->scmrepo<4,>=3.5.2->dvc) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from gitdb<5,>=4.0.1->gitpython>3->scmrepo<4,>=3.5.2->dvc) (5.0.2)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from hydra-core>=1.1->dvc) (4.9.3)
# Requirement already satisfied: PyYAML>=5.1.0 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from omegaconf->dvc) (6.0.2)
# Requirement already satisfied: appdirs in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from iterative-telemetry>=0.0.7->dvc) (1.4.4)
# Requirement already satisfied: filelock in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from iterative-telemetry>=0.0.7->dvc) (3.18.0)
# Requirement already satisfied: wcwidth in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from prompt-toolkit>=3.0.36->click-repl>=0.2.0->celery->dvc) (0.2.13)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from pydantic>=2->gto<2,>=1.6.0->dvc) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from pydantic>=2->gto<2,>=1.6.0->dvc) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from pydantic>=2->gto<2,>=1.6.0->dvc) (0.4.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from pydantic-settings>=2->gto<2,>=1.6.0->dvc) (1.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.22->dvc) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.22->dvc) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.22->dvc) (2025.6.15)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from rich>=12->dvc) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from rich>=12->dvc) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12->dvc) (0.1.2)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from typer>=0.4.1->gto<2,>=1.6.0->dvc) (1.5.4)
# Requirement already satisfied: setuptools in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from zc.lockfile>=1.2.1->dvc) (72.2.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->aiohttp-retry>=2.5.0->scmrepo<4,>=3.5.2->dvc) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->aiohttp-retry>=2.5.0->scmrepo<4,>=3.5.2->dvc) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->aiohttp-retry>=2.5.0->scmrepo<4,>=3.5.2->dvc) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->aiohttp-retry>=2.5.0->scmrepo<4,>=3.5.2->dvc) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->aiohttp-retry>=2.5.0->scmrepo<4,>=3.5.2->dvc) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\titli\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->aiohttp-retry>=2.5.0->scmrepo<4,>=3.5.2->dvc) (1.20.1)
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split

def load_data(path):
    df = pd.read_csv(path, sep="\t", header=None, names=["label", "text"])
    return df

def preprocess_data(df):
    df = df.copy()
    df["text"] = df["text"].str.lower().str.strip()
    df["label"] = df["label"].map({"ham": 0, "spam": 1})
    return df

def save_raw_data(df):
    os.makedirs("data", exist_ok=True)
    df.to_csv("data/raw_data.csv", index=False)
    print("✅ Saved raw_data.csv")

# %%
def split_data(df, seed=42):

    train_df, temp_df = train_test_split(
        df,
        test_size=0.3,
        stratify=df["label"],
        random_state=seed
    )

    val_df, test_df = train_test_split(
        temp_df,
        test_size=0.5,
        stratify=temp_df["label"],
        random_state=seed
    )

    return train_df, val_df, test_df


def save_splits(train_df, val_df, test_df):

    train_df.to_csv("data/train.csv", index=False)
    val_df.to_csv("data/validation.csv", index=False)
    test_df.to_csv("data/test.csv", index=False)

    print("✅ Saved train.csv, validation.csv, test.csv")

# %%
df = load_data("SMSSpamCollection")
df = preprocess_data(df)

save_raw_data(df)

train_df, val_df, test_df = split_data(df, seed=42)
save_splits(train_df, val_df, test_df)
# Out:
# ✅ Saved raw_data.csv
# ✅ Saved train.csv, validation.csv, test.csv

# %%
df = load_data("SMSSpamCollection")
df = preprocess_data(df)

save_raw_data(df)

train_df, val_df, test_df = split_data(df, seed=42)
save_splits(train_df, val_df, test_df)
# Out:
# ✅ Saved raw_data.csv
# ✅ Saved train.csv, validation.csv, test.csv

# %%
train_df, val_df, test_df = split_data(df, seed=99)
save_splits(train_df, val_df, test_df)
# Out:
# ✅ Saved train.csv, validation.csv, test.csv

# %%
import pandas as pd

def print_dist(file):
    df = pd.read_csv(file)
    print("\n", file)
    print(df["label"].value_counts())

print_dist("data/train.csv")
print_dist("data/validation.csv")
print_dist("data/test.csv")
# Out:
#  data/train.csv
# label
# 0    3377
# 1     523
# Name: count, dtype: int64
#
#  data/validation.csv
# label
# 0    724
# 1    112
# Name: count, dtype: int64
#
#  data/test.csv
# label
# 0    724
# 1    112
# Name: count, dtype: int64

# %%
print_dist("data/train.csv")
print_dist("data/validation.csv")
print_dist("data/test.csv")
# Out:
#  data/train.csv
# label
# 0    3377
# 1     523
# Name: count, dtype: int64
#
#  data/validation.csv
# label
# 0    724
# 1    112
# Name: count, dtype: int64
#
#  data/test.csv
# label
# 0    724
# 1    112
# Name: count, dtype: int64

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\titli\Documents\sms-spam-dvc

# %%
import pandas as pd

train = pd.read_csv(r"C:\Users\titli\Documents\sms-spam-dvc\data\train.csv")

print("VERSION 1 (seed=99) first SMS:")
print(train.iloc[0]["text"])
# Out:
# VERSION 1 (seed=99) first SMS:
# congratulations - thanks to a good friend u have won the £2,000 xmas prize. 2 claim is easy, just call 08712103738 now! only 10p per minute. bt-national-rate

# %%
import pandas as pd

train = pd.read_csv(r"C:\Users\titli\Documents\sms-spam-dvc\data\train.csv")

print("VERSION 1 (seed=42) first SMS:")
print(train.iloc[0]["text"])
# Out:
# VERSION 1 (seed=42) first SMS:
# goal! arsenal 4 (henry, 7 v liverpool 2 henry scores with a simple shot from 6 yards from a pass by bergkamp to give arsenal a 2 goal margin after 78 mins.
